# %%
import pandas as pd

pd = pd.read_csv('salary.csv', nrows = 1085, skipinitialspace = True)
pd
# Out:
#       age         workclass  fnlwgt     education  educationNum  \
# 0      39         State-gov   77516     Bachelors            13
# 1      50  Self-emp-not-inc   83311     Bachelors            13
# 2      38           Private  215646       HS-grad             9
# 3      53           Private  234721          11th             7
# 4      28           Private  338409     Bachelors            13
# ...   ...               ...     ...           ...           ...
# 1080   43           Private  173728     Bachelors            13
# 1081   19         Local-gov  167816       HS-grad             9
# 1082   58  Self-emp-not-inc   81642       HS-grad             9
# 1083   41         Local-gov  195258  Some-college            10
# 1084   31           Private  232475  Some-college            10
#
#            maritalStatus         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
pd.isna().any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# educationNum      False
# maritalStatus     False
# occupation         True
# relationship      False
# race              False
# sex               False
# captialGain       False
# capitalLoss       False
# hoursPerWeek      False
# nativeCountry      True
# incomeCategory    False
# dtype: bool

# %%
new_pd = pd.dropna()
new_pd
# Out:
#       age         workclass  fnlwgt     education  educationNum  \
# 0      39         State-gov   77516     Bachelors            13
# 1      50  Self-emp-not-inc   83311     Bachelors            13
# 2      38           Private  215646       HS-grad             9
# 3      53           Private  234721          11th             7
# 4      28           Private  338409     Bachelors            13
# ...   ...               ...     ...           ...           ...
# 1080   43           Private  173728     Bachelors            13
# 1081   19         Local-gov  167816       HS-grad             9
# 1082   58  Self-emp-not-inc   81642       HS-grad             9
# 1083   41         Local-gov  195258  Some-college            10
# 1084   31           Private  232475  Some-college            10
#
#            maritalStatus         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
new_pd = new_pd.replace({
            'State-gov': 0, 'Self-emp-not-inc': 1, 'Private': 2, 'Local-gov': 3,'Federal-gov': 4, 'Self-emp-inc': 5,
            'Never-married': 0, 'Married-civ-spouse': 1, 'Divorced': 2, 'Separated': 3, 'Married-spouse-absent': 4,
                     'Separated': 5,'Married-AF-spouse': 6, 'Widowed': 7,
            'Male': 0, 'Female': 1,
            '<=50K': 0, '>50K': 1,
            'White': 0,'Black': 1, 'Asian-Pac-Islander': 2, 'Amer-Indian-Eskimo': 3, 'Other': 4, })
new_pd
# Out:
#       age  workclass  fnlwgt     education  educationNum  maritalStatus  \
# 0      39          0   77516     Bachelors            13              0
# 1      50          1   83311     Bachelors            13              1
# 2      38          2  215646       HS-grad             9              2
# 3      53          2  234721          11th             7              1
# 4      28          2  338409     Bachelors            13              1
# ...   ...        ...     ...           ...           ...            ...
# 1080   43          2  173728     Bachelors            13              5
# 1081   19          3  167816       HS-grad             9              2
# 1082   58          1   81642       HS-grad             9              1
# 1083   41          3  195258  Some-college            10              1
# 1084   31          2  232475  Some-college            10              1
#
#              occupation   relationship  race  sex  captialGain  capitalLoss  \
# ...

# %%
salary = new_pd.drop(columns=['education', 'nativeCountry','relationship','occupation'])
salary
# Out:
#       age  workclass  fnlwgt  educationNum  maritalStatus  race  sex  \
# 0      39          0   77516            13              0     0    0
# 1      50          1   83311            13              1     0    0
# 2      38          2  215646             9              2     0    0
# 3      53          2  234721             7              1     1    0
# 4      28          2  338409            13              1     1    1
# ...   ...        ...     ...           ...            ...   ...  ...
# 1080   43          2  173728            13              5     0    1
# 1081   19          3  167816             9              2     0    1
# 1082   58          1   81642             9              1     0    0
# 1083   41          3  195258            10              1     0    0
# 1084   31          2  232475            10              1     0    0
#
#       captialGain  capitalLoss  hoursPerWeek  incomeCategory
# 0            2174            0            40               0
# ...

# %%
salary.to_csv (r'C:\Users\13462\Documents\Project\python\419 Machine Learning\locklair.csv', index = False, header=True)
