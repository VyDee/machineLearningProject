# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd
pd = pd.read_csv('machine.csv', skipinitialspace = True)
pd
# Out:
#     vendorName          model  myct  mmin   mmax  cach  chmin  chmax  prp  erp
# 0       amdahl         470v/7    29  8000  32000    32      8     32  269  253
# 1       amdahl        470v/7a    29  8000  32000    32      8     32  220  253
# 2       amdahl        470v/7b    29  8000  32000    32      8     32  172  253
# 3       amdahl        470v/7c    29  8000  16000    32      8     16  132  132
# 4       amdahl         470v/b    26  8000  32000    64      8     32  318  290
# ..         ...            ...   ...   ...    ...   ...    ...    ...  ...  ...
# 203     sperry           80/8   124  1000   8000     0      1      8   42   37
# 204     sperry  90/80-model-3    98  1000   8000    32      2      8   46   50
# 205     sratus             32   125  2000   8000     0      2     14   52   41
# 206       wang         vs-100   480   512   8000    32      0      0   67   47
# 207       wang          vs-90   480  1000   4000     0      0      0   45   25
#
# [208 rows x 10 columns]

# %%
pd = pd.drop(columns=['vendorName', 'model'])
pd
# Out:
#      myct  mmin   mmax  cach  chmin  chmax  prp  erp
# 0      29  8000  32000    32      8     32  269  253
# 1      29  8000  32000    32      8     32  220  253
# 2      29  8000  32000    32      8     32  172  253
# 3      29  8000  16000    32      8     16  132  132
# 4      26  8000  32000    64      8     32  318  290
# ..    ...   ...    ...   ...    ...    ...  ...  ...
# 203   124  1000   8000     0      1      8   42   37
# 204    98  1000   8000    32      2      8   46   50
# 205   125  2000   8000     0      2     14   52   41
# 206   480   512   8000    32      0      0   67   47
# 207   480  1000   4000     0      0      0   45   25
#
# [208 rows x 8 columns]

# %%
x = np.array(pd[pd.columns[0:7]])
x
# Out:
# array([[   29,  8000, 32000, ...,     8,    32,   269],
#        [   29,  8000, 32000, ...,     8,    32,   220],
#        [   29,  8000, 32000, ...,     8,    32,   172],
#        ...,
#        [  125,  2000,  8000, ...,     2,    14,    52],
#        [  480,   512,  8000, ...,     0,     0,    67],
#        [  480,  1000,  4000, ...,     0,     0,    45]], dtype=int64)

# %%
y = np.array(pd[pd.columns[7:8]])
y
# Out:
# array([[ 253],
#        [ 253],
#        [ 253],
#        [ 132],
#        [ 290],
#        [ 381],
#        [ 381],
#        [ 749],
#        [1238],
#        [  23],
#        [  24],
#        [  70],
#        [ 117],
#        [  15],
#        [  64],
#        [  23],
#        [  29],
#        [  22],
#        [ 124],
#        [  35],
#        [  39],
#        [  40],
#        [  45],
#        [  28],
#        [  21],
#        [  28],
#        [  22],
#        [  28],
#        [  27],
#        [ 102],
#        [ 102],
#        [  74],
#        [  74],
#        [ 138],
#        [ 136],
#        [  23],
#        [  29],
#        [  44],
#        [  30],
#        [  41],
#        [  74],
#        [  74],
#        [  74],
#        [  54],
#        [  41],
#        [  18],
#        [  28],
#        [  36],
#        [  38],
#        [  34],
#        [  19],
#        [  72],
#        [  36],
#        [  30],
#        [  56],
#        [  42],
#        [  34],
#        [  34],
#        [  34],
#        [  34],
#        [  34],
#        [  19],
#        [  75],
#        [ 113],
#        [ 157],
#        [  18],
#        [  20],
#        [  28],
#        [  33],
#        [  47],
#        [  54],
#        [  20],
#        [  23],
#        [  25],
#        [  52],
#        [  27],
#        [  50],
#        [  18],
#        [  53],
#        [  23],
#        [  30],
#        [  73],
#        [  20],
#        [  25],
#        [  28],
#        [  29],
#        [  32],
#        [ 175],
#        [  57],
#        [ 181],
#        [ 181],
#        [  32],
#        [  82],
#        [ 171],
#        [ 361],
#        [ 350],
#        [ 220],
#        [ 113],
#        [  15],
#        [  21],
#        [  35],
#        [  18],
#        [  20],
#        [  20],
#        [  28],
#        [  45],
#        [  18],
#        [  17],
#        [  26],
#        [  28],
#        [  28],
#        [  31],
#        [  31],
#        [  42],
#        [  76],
#        [  76],
#        [  26],
#        [  59],
#        [  65],
#        [ 101],
#        [ 116],
#        [  18],
#        [  20],
#        [  20],
#        [  30],
#        [  44],
#        [  44],
#        [  82],
#        [  82],
#        [ 128],
#        [  37],
#        [  46],
#        [  46],
#        [  80],
#        [  88],
#        [  88],
#        [  33],
#        [  46],
#        [  29],
#        [  53],
#        [  53],
#        [  41],
#        [  86],
#        [  95],
#        [ 107],
#        [ 117],
#        [ 119],
#        [ 120],
#        [  48],
#        [ 126],
#        [ 266],
#        [ 270],
#        [ 426],
#        [ 151],
#        [ 267],
#        [ 603],
#        [  19],
#        [  21],
#        [  26],
#        [  35],
#        [  41],
#        [  47],
#        [  62],
#        [  78],
#        [  80],
#        [  80],
#        [ 142],
#        [ 281],
#        [ 190],
#        [  21],
#        [  25],
#        [  67],
#        [  24],
#        [  24],
#        [  64],
#        [  25],
#        [  20],
#        [  29],
#        [  43],
#        [  53],
#        [  19],
#        [  22],
#        [  31],
#        [  41],
#        [  47],
#        [  99],
#        [  67],
#        [  81],
#        [ 149],
#        [ 183],
#        [ 275],
#        [ 382],
#        [  56],
#        [ 182],
#        [ 227],
#        [ 341],
#        [ 360],
#        [ 919],
#        [ 978],
#        [  24],
#        [  24],
#        [  24],
#        [  24],
#        [  37],
#        [  50],
#        [  41],
#        [  47],
#        [  25]], dtype=int64)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3)

# %%
x_train
# Out:
# array([[   56,  4000, 12000, ...,     1,     8,    42],
#        [  105,  1000,  4000, ...,     3,    24,    32],
#        [  225,  1000,  4000, ...,     3,     6,    24],
#        ...,
#        [   38,  8000, 24000, ...,     4,     8,   140],
#        [  110,  5000,  5000, ...,     8,    64,   120],
#        [  400,   512,  3500, ...,     1,     6,    40]], dtype=int64)

# %%
reg = LinearRegression().fit(x_train,y_train)

# %%
reg.predict(x_test)
# Out:
# array([[ 1.03441307e+01],
#        [ 1.19851595e+02],
#        [ 6.13338067e+01],
#        [ 1.76282163e+01],
#        [-1.05537980e+01],
#        [-1.44132926e+01],
#        [ 5.96738633e+01],
#        [-1.96857831e+00],
#        [-1.42117468e+01],
#        [ 1.08266454e+02],
#        [ 6.38705519e+01],
#        [ 5.99731603e+01],
#        [ 3.83333467e+02],
#        [ 4.62873261e+01],
#        [ 2.32660472e+02],
#        [-2.62455465e+00],
#        [ 4.61320222e+01],
#        [ 3.73325344e+01],
#        [ 3.81461419e+01],
#        [ 3.69370504e+01],
#        [ 1.36401725e+02],
#        [ 2.99210124e+02],
#        [ 1.55016075e+01],
#        [ 1.50442313e+01],
#        [ 1.76083632e+01],
#        [ 1.96174457e+01],
#        [ 1.33689150e+02],
#        [ 4.00865049e+01],
#        [ 8.94531408e+00],
#        [ 2.92449546e+00],
#        [ 7.74214498e+01],
#        [ 3.51846393e+01],
#        [ 9.93586548e+01],
#        [ 3.40498324e+01],
#        [ 2.33871849e+01],
#        [ 7.85383758e+00],
#        [ 3.20658842e+01],
#        [ 4.02614720e+01],
#        [ 1.59616558e-02],
#        [ 9.85832745e+01],
#        [ 2.24880511e+01],
#        [ 6.75236275e+01],
#        [ 2.04848987e+02],
#        [ 1.99956271e+02],
#        [-2.68116607e+00],
#        [ 1.46010614e+01],
#        [ 5.69734883e+01],
#        [ 4.94257209e+02],
#        [ 1.09571881e+02],
#        [ 9.50679957e-02],
#        [ 9.62584793e+02],
#        [ 3.14894730e+01],
#        [ 2.30051183e+01],
#        [ 3.38402883e+01],
#        [ 1.95078001e+02],
#        [ 4.13143789e+00],
#        [ 2.79978789e+02],
#        [ 1.25968022e+02],
#        [ 2.38717097e+02],
#        [ 1.65349086e+01],
#        [ 2.15603688e+00],
#        [ 1.96057768e+01],
#        [-9.22676040e+00]])

# %%
#check the accuracy 
reg.score(x_test,y_test)
# Out:
# 0.9766392522523316
